# %% [markdown]
# # 01.02 - Estructuras de Datos en Python
#
# **Autor:** Miguel Ángel Vázquez Varela
# **Nivel:** Fundamentos
# **Tiempo estimado:** 30 min

# %% [markdown]
# ---
#
# ## ¿Qué aprenderás?
#
# - **Listas**: colecciones ordenadas y modificables
# - **Tuplas**: colecciones ordenadas e inmutables
# - **Diccionarios**: pares clave-valor
# - **Sets**: colecciones sin duplicados
# - Cuándo usar cada una

# %% [markdown]
# ---
#
# ## 1. Listas (`list`)
#
# La estructura más versátil. Ordenada, modificable, permite duplicados.

# %% [markdown]
# ### Crear listas

# %%
# Lista vacía
empty_list = []

# Lista con elementos
stations = ["Sol", "Atocha", "Cibeles", "Retiro"]
print(f"Estaciones: {stations}")
# Out:
# Estaciones: ['Sol', 'Atocha', 'Cibeles', 'Retiro']

# %%
# Listas pueden tener diferentes tipos (aunque no es recomendable)
mixed = ["Sol", 42, 3.14, True]
print(f"Lista mixta: {mixed}")
# Out:
# Lista mixta: ['Sol', 42, 3.14, True]

# %% [markdown]
# ### Acceder a elementos
#
# Los índices empiezan en **0**.

# %%
stations = ["Sol", "Atocha", "Cibeles", "Retiro"]

print(f"Primera estación: {stations[0]}")
print(f"Última estación: {stations[-1]}")
# Out:
# Primera estación: Sol
# Última estación: Retiro

# %% [markdown]
# ### Slicing (extraer sublistas)

# %%
stations = ["Sol", "Atocha", "Cibeles", "Retiro", "Moncloa"]

# [inicio:fin] - fin NO incluido
print(f"Primeras 3: {stations[0:3]}")
print(f"Desde la 2ª: {stations[1:]}")
print(f"Últimas 2: {stations[-2:]}")
# Out:
# Primeras 3: ['Sol', 'Atocha', 'Cibeles']
# Desde la 2ª: ['Atocha', 'Cibeles', 'Retiro', 'Moncloa']
# Últimas 2: ['Retiro', 'Moncloa']

# %% [markdown]
# ### Modificar listas

# %%
stations = ["Sol", "Atocha"]

# Añadir al final
stations.append("Cibeles")
print(f"Después de append: {stations}")
# Out:
# Después de append: ['Sol', 'Atocha', 'Cibeles']

# %%
# Insertar en posición específica
stations.insert(1, "Gran Vía")
print(f"Después de insert: {stations}")
# Out:
# Después de insert: ['Sol', 'Gran Vía', 'Atocha', 'Cibeles']

# %%
# Eliminar por valor
stations.remove("Gran Vía")
print(f"Después de remove: {stations}")
# Out:
# Después de remove: ['Sol', 'Atocha', 'Cibeles']

# %%
# Eliminar por índice
removed = stations.pop(0)
print(f"Eliminado: {removed}")
print(f"Lista actual: {stations}")
# Out:
# Eliminado: Sol
# Lista actual: ['Atocha', 'Cibeles']

# %% [markdown]
# ### Operaciones útiles

# %%
durations = [15, 22, 8, 35, 12]

print(f"Longitud: {len(durations)}")
print(f"Suma: {sum(durations)}")
print(f"Mínimo: {min(durations)}")
print(f"Máximo: {max(durations)}")
# Out:
# Longitud: 5
# Suma: 92
# Mínimo: 8
# Máximo: 35

# %%
# Ordenar
durations.sort()
print(f"Ordenada: {durations}")

durations.sort(reverse=True)
print(f"Descendente: {durations}")
# Out:
# Ordenada: [8, 12, 15, 22, 35]
# Descendente: [35, 22, 15, 12, 8]

# %%
# Comprobar si existe
print(f"¿Está 22?: {22 in durations}")
print(f"¿Está 100?: {100 in durations}")
# Out:
# ¿Está 22?: True
# ¿Está 100?: False

# %% [markdown]
# ---
#
# ## 2. Tuplas (`tuple`)
#
# Similar a listas pero **inmutables** (no se pueden modificar después de crear).

# %%
# Crear tupla
coordinates = (40.4168, -3.7038)
print(f"Coordenadas: {coordinates}")
print(f"Latitud: {coordinates[0]}")
# Out:
# Coordenadas: (40.4168, -3.7038)
# Latitud: 40.4168

# %% [markdown]
# Las tuplas no se pueden modificar:

# %%
# Esto daría error:
# coordinates[0] = 41.0  # TypeError!

print("Las tuplas son inmutables")
# Out:
# Las tuplas son inmutables

# %% [markdown]
# ### ¿Cuándo usar tuplas?
#
# - Datos que no deben cambiar (coordenadas, configuraciones)
# - Retornar múltiples valores de una función
# - Como claves de diccionario (las listas no pueden)

# %%
# Desempaquetar tuplas
lat, lon = coordinates
print(f"Latitud: {lat}")
print(f"Longitud: {lon}")
# Out:
# Latitud: 40.4168
# Longitud: -3.7038

# %% [markdown]
# ---
#
# ## 3. Diccionarios (`dict`)
#
# Pares **clave-valor**. Perfectos para datos estructurados.

# %% [markdown]
# ### Crear diccionarios

# %%
# Diccionario vacío
empty_dict = {}

# Diccionario con datos
station = {
    "name": "Sol",
    "bikes": 15,
    "docks": 30,
    "active": True
}

print(station)
# Out:
# {'name': 'Sol', 'bikes': 15, 'docks': 30, 'active': True}

# %% [markdown]
# ### Acceder a valores

# %%
# Por clave
print(f"Nombre: {station['name']}")
print(f"Bicis: {station['bikes']}")
# Out:
# Nombre: Sol
# Bicis: 15

# %%
# Con .get() - más seguro (no da error si no existe)
print(f"Ciudad: {station.get('city', 'No especificada')}")
# Out:
# Ciudad: No especificada

# %% [markdown]
# ### Modificar diccionarios

# %%
# Añadir o modificar
station["city"] = "Madrid"
station["bikes"] = 12

print(station)
# Out:
# {'name': 'Sol', 'bikes': 12, 'docks': 30, 'active': True, 'city': 'Madrid'}

# %% [markdown]
# ### Iterar sobre diccionarios

# %%
# Solo claves
for key in station:
    print(f"Clave: {key}")
# Out:
# Clave: name
# Clave: bikes
# Clave: docks
# Clave: city

# %%
# Claves y valores
for key, value in station.items():
    print(f"{key}: {value}")
# Out:
# name: Sol
# bikes: 12
# docks: 30
# city: Madrid

# %% [markdown]
# ### Lista de diccionarios
#
# Muy común en datos reales (cada fila = diccionario):

# %%
stations = [
    {"name": "Sol", "bikes": 15, "docks": 30},
    {"name": "Atocha", "bikes": 8, "docks": 25},
    {"name": "Cibeles", "bikes": 22, "docks": 35}
]

for s in stations:
    print(f"{s['name']}: {s['bikes']}/{s['docks']} bicis")
# Out:
# Sol: 15/30 bicis
# Atocha: 8/25 bicis
# Cibeles: 22/35 bicis

# %% [markdown]
# ---
#
# ## 4. Sets (`set`)
#
# Colección **sin duplicados** y sin orden. Útil para operaciones de conjuntos.

# %%
# Crear set
cities = {"Madrid", "Barcelona", "Valencia", "Madrid"}
print(f"Set: {cities}")  # Madrid solo aparece una vez
# Out:
# Set: {'Madrid', 'Barcelona', 'Valencia'}

# %%
# Eliminar duplicados de una lista
trips = ["Sol", "Atocha", "Sol", "Cibeles", "Atocha"]
unique_stations = set(trips)
print(f"Estaciones únicas: {unique_stations}")
# Out:
# Estaciones únicas: {'Atocha', 'Sol', 'Cibeles'}

# %% [markdown]
# ### Operaciones de conjuntos

# %%
morning_users = {"user1", "user2", "user3", "user4"}
evening_users = {"user3", "user4", "user5", "user6"}

# %%
# Unión (todos)
all_users = morning_users | evening_users
print(f"Todos los usuarios: {all_users}")
# Out:
# Todos los usuarios: {'user1', 'user2', 'user6', 'user4', 'user3', 'user5'}

# %%
# Intersección (comunes)
both = morning_users & evening_users
print(f"Usuarios mañana Y tarde: {both}")
# Out:
# Usuarios mañana Y tarde: {'user4', 'user3'}

# %%
# Diferencia (solo en uno)
only_morning = morning_users - evening_users
print(f"Solo por la mañana: {only_morning}")
# Out:
# Solo por la mañana: {'user1', 'user2'}

# %% [markdown]
# ---
#
# ## 5. ¿Cuál usar?
#
# | Estructura | Ordenada | Modificable | Duplicados | Uso típico |
# |------------|----------|-------------|------------|------------|
# | `list` | ✅ | ✅ | ✅ | Colección general |
# | `tuple` | ✅ | ❌ | ✅ | Datos fijos, retornos |
# | `dict` | ✅* | ✅ | Claves únicas | Datos estructurados |
# | `set` | ❌ | ✅ | ❌ | Valores únicos |
#
# *Desde Python 3.7, los diccionarios mantienen el orden de inserción.

# %% [markdown]
# ---
#
# ## 💡 Resumen

# %%
# Lista - colección ordenada
my_list = [1, 2, 3]

# Tupla - inmutable
my_tuple = (1, 2, 3)

# Diccionario - clave:valor
my_dict = {"a": 1, "b": 2}

# Set - sin duplicados
my_set = {1, 2, 3}

print(f"Lista: {my_list}")
print(f"Tupla: {my_tuple}")
print(f"Dict: {my_dict}")
print(f"Set: {my_set}")
# Out:
# Lista: [1, 2, 3]
# Tupla: (1, 2, 3)
# Dict: {'a': 1, 'b': 2}
# Set: {1, 2, 3}

# %% [markdown]
# ---
#
# ## 🏋️ Ejercicio
#
# Tienes datos de viajes. Crea:
# 1. Una lista de diccionarios con 3 viajes (cada uno con `station`, `duration`, `user_id`)
# 2. Obtén la lista de usuarios únicos
# 3. Calcula la duración total

# %%
# Tu código aquí
trips = [
    {"station": "Sol", "duration": 15, "user_id": "u001"},
    {"station": "Atocha", "duration": 22, "user_id": "u002"},
    {"station": "Sol", "duration": 8, "user_id": "u001"}
]

# Usuarios únicos
users = set(t["user_id"] for t in trips)
print(f"Usuarios únicos: {users}")

# Duración total
total = sum(t["duration"] for t in trips)
print(f"Duración total: {total} min")
# Out:
# Usuarios únicos: {'u002', 'u001'}
# Duración total: 45 min

# %% [markdown]
# ---
#
# **Anterior:** [01.01 - Variables y Tipos](./01_01_variables_and_types.ipynb)
# **Siguiente:** [01.03 - Control de Flujo](./01_03_control_flow.ipynb)

# %% [markdown]
# # 01 - Variables y Tipos de Datos en Python
#
# **Autor:** Miguel Ángel Vázquez Varela
# **Nivel:** Fundamentos
# **Tiempo estimado:** 20 min

# %% [markdown]
# ---
#
# ## ¿Qué aprenderás?
#
# - Crear y nombrar variables correctamente
# - Entender los tipos de datos básicos
# - Conversión entre tipos (casting)
# - Buenas prácticas de naming

# %% [markdown]
# ---
#
# ## 1. ¿Qué es una variable?
#
# Una variable es un **nombre** que apunta a un **valor** en memoria.
#
# En Python no necesitas declarar el tipo — se infiere automáticamente.

# %%
# Creamos nuestra primera variable
nombre = "Miguel"
print(nombre)
# Out:
# Miguel

# %% [markdown]
# Podemos crear variables de diferentes tipos sin declarar nada especial:

# %%
edad = 30           # número entero
altura = 1.75       # número decimal
es_analista = True  # booleano (verdadero/falso)

print(f"Edad: {edad}")
print(f"Altura: {altura}m")
print(f"¿Es analista?: {es_analista}")
# Out:
# Edad: 30
# Altura: 1.75m
# ¿Es analista?: True

# %% [markdown]
# ---
#
# ## 2. Convenciones de nombres (PEP 8)
#
# Python tiene un estilo oficial de código llamado **PEP 8**.
#
# | Estilo | Uso | Ejemplo |
# |--------|-----|--------|
# | `snake_case` | Variables, funciones | `total_trips` |
# | `UPPER_CASE` | Constantes | `MAX_SPEED` |
# | `PascalCase` | Clases | `DataProcessor` |

# %%
# ✅ Bien - snake_case para variables
trip_count = 100
average_duration = 15.5

# %%
# ❌ Evitar estos estilos
tripCount = 100      # camelCase (estilo Java)
x = 100              # nombres no descriptivos

# %% [markdown]
# ---
#
# ## 3. Tipos de datos básicos
#
# Python tiene 4 tipos fundamentales que usarás constantemente.

# %% [markdown]
# ### 3.1 Integers (`int`)
#
# Números enteros, sin decimales. Perfectos para conteos e IDs.

# %%
num_stations = 850
year = 2024

print(f"Estaciones: {num_stations}")
print(f"Tipo: {type(num_stations)}")
# Out:
# Estaciones: 850
# Tipo: <class 'int'>

# %% [markdown]
# ### 3.2 Floats (`float`)
#
# Números decimales. Usados para medidas, promedios, coordenadas.

# %%
avg_trip_duration = 12.5  # minutos
latitude = 40.4168

print(f"Duración media: {avg_trip_duration} min")
print(f"Tipo: {type(latitude)}")
# Out:
# Duración media: 12.5 min
# Tipo: <class 'float'>

# %% [markdown]
# ⚠️ **Cuidado**: Los floats pueden tener errores de precisión:

# %%
# ¿Esperabas 0.3?
resultado = 0.1 + 0.2
print(f"0.1 + 0.2 = {resultado}")
# Out:
# 0.1 + 0.2 = 0.30000000000000004

# %% [markdown]
# Por esto, nunca compares floats directamente. Usa una tolerancia:

# %%
# ❌ No hagas esto
print(f"Comparación directa: {resultado == 0.3}")

# ✅ Usa tolerancia
print(f"Con tolerancia: {abs(resultado - 0.3) < 0.0001}")
# Out:
# Comparación directa: False
# Con tolerancia: True

# %% [markdown]
# ### 3.3 Strings (`str`)
#
# Texto. Se pueden usar comillas simples `'texto'` o dobles `"texto"`.

# %%
city = "Madrid"
station_name = 'Puerta del Sol'

print(f"Ciudad: {city}")
print(f"Tipo: {type(city)}")
# Out:
# Ciudad: Madrid
# Tipo: <class 'str'>

# %% [markdown]
# ### 3.4 Booleans (`bool`)
#
# Solo dos valores posibles: `True` o `False`. Muy usados en filtros y condiciones.

# %%
is_weekend = False
has_bikes = True

print(f"¿Es fin de semana?: {is_weekend}")
print(f"Tipo: {type(is_weekend)}")
# Out:
# ¿Es fin de semana?: False
# Tipo: <class 'bool'>

# %% [markdown]
# ---
#
# ## 4. Operaciones básicas

# %% [markdown]
# ### 4.1 Operaciones aritméticas

# %%
total_trips = 1000
days = 30

# División normal (devuelve float)
trips_per_day = total_trips / days
print(f"Viajes por día: {trips_per_day}")
# Out:
# Viajes por día: 33.333333333333336

# %%
# División entera (descarta decimales)
trips_per_day_int = total_trips // days
print(f"Viajes por día (entero): {trips_per_day_int}")
# Out:
# Viajes por día (entero): 33

# %%
# Módulo (resto de la división)
remainder = total_trips % days
print(f"Resto: {remainder}")
# Out:
# Resto: 10

# %%
# Potencia
squared = days ** 2
print(f"30 al cuadrado: {squared}")
# Out:
# 30 al cuadrado: 900

# %% [markdown]
# ### 4.2 Operaciones con strings

# %%
first_name = "Miguel"
last_name = "Vázquez"

# Concatenación con +
full_name = first_name + " " + last_name
print(f"Nombre completo: {full_name}")
# Out:
# Nombre completo: Miguel Vázquez

# %%
# Repetición con *
separator = "-" * 20
print(separator)
# Out:
# --------------------

# %% [markdown]
# La forma más moderna y legible de combinar strings son los **f-strings**:

# %%
age = 30
intro = f"Me llamo {first_name} y tengo {age} años"
print(intro)
# Out:
# Me llamo Miguel y tengo 30 años

# %% [markdown]
# ---
#
# ## 5. Conversión de tipos (Casting)
#
# A veces necesitas convertir un tipo a otro. Esto es muy común al leer datos externos.

# %% [markdown]
# ### De string a número
#
# Típico cuando lees datos de un CSV o input del usuario:

# %%
price_str = "25.99"
quantity_str = "3"

# Convertir a números
price = float(price_str)
quantity = int(quantity_str)

total = price * quantity
print(f"Total: {total}€")
# Out:
# Total: 77.97€

# %% [markdown]
# ### De número a string
#
# Útil para construir nombres de archivos o mensajes:

# %%
year = 2024

# Forma clásica
filename = "data_" + str(year) + ".csv"
print(f"Archivo: {filename}")

# Mejor con f-string (más legible)
filename_better = f"data_{year}.csv"
print(f"Archivo: {filename_better}")
# Out:
# Archivo: data_2024.csv
# Archivo: data_2024.csv

# %% [markdown]
# ### Conversión a boolean
#
# Todo en Python se puede convertir a `True` o `False`:

# %%
# Valores "falsy" → se convierten a False
print(f"bool(0): {bool(0)}")
print(f"bool(''): {bool('')}")
print(f"bool(None): {bool(None)}")
# Out:
# bool(0): False
# bool(''): False
# bool(None): False

# %%
# Todo lo demás es "truthy" → True
print(f"bool(1): {bool(1)}")
print(f"bool('texto'): {bool('texto')}")
print(f"bool(-5): {bool(-5)}")
# Out:
# bool(1): True
# bool('texto'): True
# bool(-5): True

# %% [markdown]
# ---
#
# ## 6. None: la ausencia de valor
#
# `None` representa "sin valor". Es equivalente a `NULL` en SQL o `NA` en R.

# %%
result = None

# Para comprobar si algo es None, usa 'is'
if result is None:
    print("No hay resultado todavía")
# Out:
# No hay resultado todavía

# %% [markdown]
# ⚠️ Usa siempre `is None`, no `== None`:

# %%
# ✅ Correcto
print(f"result is None: {result is None}")

# ❌ Funciona pero no es idiomático
print(f"result == None: {result == None}")
# Out:
# result is None: True
# result == None: True

# %% [markdown]
# ---
#
# ## 💡 Resumen
#
# | Tipo | Ejemplo | Uso típico |
# |------|---------|------------|
# | `int` | `42` | Conteos, IDs |
# | `float` | `3.14` | Medidas, coordenadas |
# | `str` | `"texto"` | Nombres, categorías |
# | `bool` | `True` | Flags, filtros |
# | `None` | `None` | Valor ausente |

# %% [markdown]
# ---
#
# ## 🏋️ Ejercicio
#
# Crea variables para representar una estación de bicicletas con:
# - Nombre de la estación (string)
# - Número de bicis disponibles (int)
# - Latitud y longitud (floats)
# - Si tiene estacionamiento para bicis eléctricas (bool)

# %%
# Tu código aquí
station_name = "Atocha"
bikes_available = 12
latitude = 40.4065
longitude = -3.6895
has_electric = True

# Imprime un resumen
print(f"Estación: {station_name}")
print(f"Ubicación: ({latitude}, {longitude})")
print(f"Bicis disponibles: {bikes_available}")
print(f"Admite eléctricas: {has_electric}")
# Out:
# Estación: Atocha
# Ubicación: (40.4065, -3.6895)
# Bicis disponibles: 12
# Admite eléctricas: True

# %% [markdown]
# ---
#
# **Siguiente:** [02 - Funciones](../02_functions_and_modules/02_functions_basics.ipynb)
